# %% [markdown]
# <a href="https://colab.research.google.com/github/NeonLabs146/General_stuffs/blob/main/Excellence_survey_MBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('MBM College Excellence Survey.csv')
df.head()
# Out:
#                          Timestamp                 Name  \
# 0   2025/01/13 2:06:52 PM GMT+5:45      Rhishav Poudyal
# 1  2025/01/15 12:59:18 PM GMT+5:45      Sameena Bhandai
# 2   2025/01/15 1:11:42 PM GMT+5:45        Anista Amatya
# 3   2025/01/15 1:13:12 PM GMT+5:45  Prabeshika Adhikari
# 4   2025/01/15 1:13:17 PM GMT+5:45               Susma
#
#                           email:  \
# 0      rhishav.poudyal@gmail.com
# 1     sameena7716@mbmcsit.edu.np
# 2      anista7704@mbmcsit.edu.np
# 3  prabeshikaadhikari6@gmail.com
# 4      timilsenasusma5@gmail.com
#
#   What is your relationship with Madan Bhandari Memorial College?  \
# 0                                      Staff/Faculty
# 1                                    Current Student
# 2                                    Current Student
# 3                                    Current Student
# 4                                    Current Student
#
#   How long have you been associated with or aware of the college?  \
# 0                                  more than 3 years
# 1                                  more than 3 years
# 2                                  more than 3 years
# 3                                   less than 1 year
# 4                                   less than 1 year
#
#    How you rate the college overall?  \
# 0                                3.0
# 1                                4.0
# 2                                3.0
# 3                                3.0
# 4                                3.0
#
#   How would you rate the academic standards of the college?  \
# 0                                               Good
# 1                                               Fair
# 2                                               Good
# 3                                               Good
# 4                                               Good
#
#   Are you satisfied with the teaching quality of the faculty?  \
# 0                                          Satisfied
# 1                                            Neutral
# 2                                          Satisfied
# 3                                            Neutral
# 4                                            Neutral
#
#   What do you think about the curriculum and its relevance to industry standards?  \
# 0                                           Relavent
# 1                                           Relavent
# 2                                            Neutral
# 3                                            Neutral
# 4                                            Neutral
#
#   Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?  \
# 0                                                 No
# 1                                          Partially
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?  \
# 0                                                3.0
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Are extracurricular activities and sports adequately promoted at the college?  \
# 0                                                 No
# 1                                                Yes
# 2                                          Partially
# 3                                                Yes
# 4                                                Yes
#
#   How satisfied are you with the cleanliness and maintenance of the campus?  \
# 0                                                2.0
# 1                                                4.0
# 2                                                4.0
# 3                                                3.0
# 4                                                3.0
#
#    How would you rate the career guidance and placement opportunities provided by the college?  \
# 0                                               Good
# 1                                               Fair
# 2                                               Good
# 3                                               Fair
# 4                                               Fair
#
#   Does the college provide adequate emotional and academic support to students?  \
# 0                                                 No
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
#
#   Do you feel valued and respected as a student/community member of the college?  \
# 0                                                 No
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
#
#   How likely are you to recommend this college to others?  \
# 0                                             Likely
# 1                                             Likely
# 2                                        Very likely
# 3                                            Neutral
# 4                                            Neutral
#
#   What are the top three strengths of the college? (Open-ended)  \
# 0                                               A bc
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What are the top three areas where the college needs improvement? (Open-ended)  \
# 0                                               D ef
# 1                                                NaN
# 2  add more extra curriculum activities, facilita...
# 3                                                NaN
# 4                                                NaN
#
#   Please share any additional comments or experiences regarding the college. (Open-ended)
# 0                                                Xyz
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
df.drop(index=0, inplace=True)
df.head()
# Out:
#                          Timestamp                 Name  \
# 1  2025/01/15 12:59:18 PM GMT+5:45      Sameena Bhandai
# 2   2025/01/15 1:11:42 PM GMT+5:45        Anista Amatya
# 3   2025/01/15 1:13:12 PM GMT+5:45  Prabeshika Adhikari
# 4   2025/01/15 1:13:17 PM GMT+5:45               Susma
# 5   2025/01/15 1:14:05 PM GMT+5:45    Sudikshya Khadka
#
#                           email:  \
# 1     sameena7716@mbmcsit.edu.np
# 2      anista7704@mbmcsit.edu.np
# 3  prabeshikaadhikari6@gmail.com
# 4      timilsenasusma5@gmail.com
# 5    Sudikshyakhadka12@gmail.com
#
#   What is your relationship with Madan Bhandari Memorial College?  \
# 1                                    Current Student
# 2                                    Current Student
# 3                                    Current Student
# 4                                    Current Student
# 5                                    Current Student
#
#   How long have you been associated with or aware of the college?  \
# 1                                  more than 3 years
# 2                                  more than 3 years
# 3                                   less than 1 year
# 4                                   less than 1 year
# 5                                  more than 3 years
#
#    How you rate the college overall?  \
# 1                                4.0
# 2                                3.0
# 3                                3.0
# 4                                3.0
# 5                                3.0
#
#   How would you rate the academic standards of the college?  \
# 1                                               Fair
# 2                                               Good
# 3                                               Good
# 4                                               Good
# 5                                               Good
#
#   Are you satisfied with the teaching quality of the faculty?  \
# 1                                            Neutral
# 2                                          Satisfied
# 3                                            Neutral
# 4                                            Neutral
# 5                                            Neutral
#
#   What do you think about the curriculum and its relevance to industry standards?  \
# 1                                           Relavent
# 2                                            Neutral
# 3                                            Neutral
# 4                                            Neutral
# 5                                            Neutral
#
#   Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?  \
# 1                                          Partially
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
#
#    ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
# 5  ...
#
#   How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?  \
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
# 5                                                3.0
#
#    Are extracurricular activities and sports adequately promoted at the college?  \
# 1                                                Yes
# 2                                          Partially
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
#
#   How satisfied are you with the cleanliness and maintenance of the campus?  \
# 1                                                4.0
# 2                                                4.0
# 3                                                3.0
# 4                                                3.0
# 5                                                3.0
#
#    How would you rate the career guidance and placement opportunities provided by the college?  \
# 1                                               Fair
# 2                                               Good
# 3                                               Fair
# 4                                               Fair
# 5                                               Good
#
#   Does the college provide adequate emotional and academic support to students?  \
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
#
#   Do you feel valued and respected as a student/community member of the college?  \
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
#
#   How likely are you to recommend this college to others?  \
# 1                                             Likely
# 2                                        Very likely
# 3                                            Neutral
# 4                                            Neutral
# 5                                            Neutral
#
#   What are the top three strengths of the college? (Open-ended)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   What are the top three areas where the college needs improvement? (Open-ended)  \
# 1                                                NaN
# 2  add more extra curriculum activities, facilita...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Please share any additional comments or experiences regarding the college. (Open-ended)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 1 to 349
# Data columns (total 21 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   Timestamp                                                                                                          349 non-null    object
#  1   Name                                                                                                               345 non-null    object
#  2   email:                                                                                                             343 non-null    object
#  3   What is your relationship with Madan Bhandari Memorial College?                                                    347 non-null    object
#  4   How long have you been associated with or aware of the college?                                                    348 non-null    object
#  5   How you rate the college overall?                                                                                  347 non-null    float64
#  6   How would you rate the academic standards of the college?                                                          349 non-null    object
#  7   Are you satisfied with the teaching quality of the faculty?                                                        347 non-null    object
#  8   What do you think about the curriculum and its relevance to industry standards?                                    343 non-null    object
#  9   Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?  347 non-null    object
#  10  Please share any suggestions for improving academic excellence at the college. (Open-ended)                        157 non-null    object
#  11  How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?                     346 non-null    float64
#  12  Are extracurricular activities and sports adequately promoted at the college?                                      345 non-null    object
#  13  How satisfied are you with the cleanliness and maintenance of the campus?                                          343 non-null    float64
#  14  How would you rate the career guidance and placement opportunities provided by the college?                        340 non-null    object
#  15  Does the college provide adequate emotional and academic support to students?                                      341 non-null    object
#  16  Do you feel valued and respected as a student/community member of the college?                                     337 non-null    object
#  17  How likely are you to recommend this college to others?                                                            343 non-null    object
#  18  What are the top three strengths of the college? (Open-ended)                                                      155 non-null    object
#  19  What are the top three areas where the college needs improvement? (Open-ended)                                     165 non-null    object
#  20  Please share any additional comments or experiences regarding the college. (Open-ended)                            93 non-null     object
# dtypes: float64(3), object(18)
# memory usage: 57.4+ KB

# %%
df.describe()
# Out:
#        How you rate the college overall?  \
# count                         347.000000
# mean                            3.478386
# std                             1.006608
# min                             1.000000
# 25%                             3.000000
# 50%                             4.000000
# 75%                             4.000000
# max                             5.000000
#
#        How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?  \
# count                                         346.000000
# mean                                            3.427746
# std                                             1.025322
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        How satisfied are you with the cleanliness and maintenance of the campus?
# count                                         343.000000
# mean                                            3.653061
# std                                             1.031258
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %%
df['Are you satisfied with the teaching quality of the faculty?'].describe()
# Out:
# count           347
# unique            4
# top       Satisfied
# freq            171
# Name: Are you satisfied with the teaching quality of the faculty?, dtype: object

# %%
df['How long have you been associated with or aware of the college?'].describe()
# Out:
# count           348
# unique            3
# top       1-3 years
# freq            149
# Name: How long have you been associated with or aware of the college?, dtype: object

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                              0
# Name                                                                                                                   4
# email:                                                                                                                 6
# What is your relationship with Madan Bhandari Memorial College?                                                        2
# How long have you been associated with or aware of the college?                                                        1
# How you rate the college overall?                                                                                      2
# How would you rate the academic standards of the college?                                                              0
# Are you satisfied with the teaching quality of the faculty?                                                            2
# What do you think about the curriculum and its relevance to industry standards?                                        6
# Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?      2
# Please share any suggestions for improving academic excellence at the college. (Open-ended)                          192
# How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?                         3
# Are extracurricular activities and sports adequately promoted at the college?                                          4
# How satisfied are you with the cleanliness and maintenance of the campus?                                              6
# How would you rate the career guidance and placement opportunities provided by the college?                            9
# Does the college provide adequate emotional and academic support to students?                                          8
# Do you feel valued and respected as a student/community member of the college?                                        12
# How likely are you to recommend this college to others?                                                                6
# What are the top three strengths of the college? (Open-ended)                                                        194
# What are the top three areas where the college needs improvement? (Open-ended)                                       184
# Please share any additional comments or experiences regarding the college. (Open-ended)                              256
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
# !pip install ydata-profiling
import ydata_profiling as pandas_profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.10.6)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.61.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.1.31)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 8.4 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.3 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 27.7 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 89.9 MB/s eta 0:00:00
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.0 MB/s eta 0:00:00
# Downloading wordcloud-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 28.8 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 12.7 MB/s eta 0:00:00
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.6 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 96.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (pyproject.toml) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27160 sha256=a2dafb3ad46717a18b4a7129b40f246b83ce109e242510e5557424054e9606b3
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, typeguard, PyWavelets, patsy, multimethod, dacite, imagehash, wordcloud, visions, statsmodels, phik, ydata-profiling
# Successfully installed PyWavelets-1.8.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 patsy-1.0.1 phik-0.12.4 puremagic-1.28 statsmodels-0.14.4 typeguard-4.4.2 visions-0.8.1 wordcloud-1.9.4 ydata-profiling-4.16.1
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='MBM.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# 100%|██████████| 21/21 [00:00<00:00, 152.89it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
selected_columns = df[['How long have you been associated with or aware of the college?',
                       'How you rate the college overall?',
                       'How would you rate the academic standards of the college?',
                       'Are you satisfied with the teaching quality of the faculty?',
                       'What do you think about the curriculum and its relevance to industry standards?',
                       'Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?',
                       'How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?',
                       'Are extracurricular activities and sports adequately promoted at the college?',
                       'How satisfied are you with the cleanliness and maintenance of the campus?',
                       'How would you rate the career guidance and placement opportunities provided by the college?',
                       'Does the college provide adequate emotional and academic support to students?',
                       'Do you feel valued and respected as a student/community member of the college?',
                       'How likely are you to recommend this college to others?'

                       ]]
new_df = selected_columns.rename(columns = {'How long have you been associated with or aware of the college?':'College Association',
                                            'How you rate the college overall?':'College_rate',
                                            'How would you rate the academic standards of the college?':'Academic_standard',
                                            'Are you satisfied with the teaching quality of the faculty?':'Teaching_quality',
                                            'What do you think about the curriculum and its relevance to industry standards?':'Curriculum_relevance',
                                            'Do you think the college provides adequate resources (library, labs, online resources, etc.) to support learning?':'Academic_Resources',
                                            'How would you rate the college’s infrastructure (classrooms, labs, internet facilities, etc.)?':'College-infracture',
                                            'Are extracurricular activities and sports adequately promoted at the college?':'extracurricular-activities',
                                            'How satisfied are you with the cleanliness and maintenance of the campus?':'Hygene',
                                            'How would you rate the career guidance and placement opportunities provided by the college?':'Career_guide',
                                            'Does the college provide adequate emotional and academic support to students?':'Support',
                                            'Do you feel valued and respected as a student/community member of the college?':'Social_value',
                                            'How likely are you to recommend this college to others?':'Recommendation-others'
                                            })

new_df.head()
# Out:
#   College Association  College_rate Academic_standard Teaching_quality  \
# 1   more than 3 years           4.0              Fair          Neutral
# 2   more than 3 years           3.0              Good        Satisfied
# 3    less than 1 year           3.0              Good          Neutral
# 4    less than 1 year           3.0              Good          Neutral
# 5   more than 3 years           3.0              Good          Neutral
#
#   Curriculum_relevance Academic_Resources  College-infracture  \
# 1             Relavent          Partially                 4.0
# 2              Neutral                Yes                 4.0
# 3              Neutral                Yes                 4.0
# 4              Neutral                Yes                 4.0
# 5              Neutral                Yes                 3.0
#
#   extracurricular-activities  Hygene Career_guide Support Social_value  \
# 1                        Yes     4.0         Fair   Maybe        Maybe
# 2                  Partially     4.0         Good   Maybe        Maybe
# 3                        Yes     3.0         Fair     Yes          Yes
# 4                        Yes     3.0         Fair     Yes          Yes
# 5                        Yes     3.0         Good     Yes          Yes
#
#   Recommendation-others
# 1                Likely
# 2           Very likely
# 3               Neutral
# 4               Neutral
# 5               Neutral

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# One-hot encode nominal categorical columns
nominal_cols = ['College Association', 'Academic_Resources', 'extracurricular-activities', 'Support', 'Social_value']
df_encoded = pd.get_dummies(new_df, columns=nominal_cols, drop_first=True)
df_encoded.head(10)
# Out:
#     College_rate Academic_standard Teaching_quality Curriculum_relevance  \
# 1            4.0              Fair          Neutral             Relavent
# 2            3.0              Good        Satisfied              Neutral
# 3            3.0              Good          Neutral              Neutral
# 4            3.0              Good          Neutral              Neutral
# 5            3.0              Good          Neutral              Neutral
# 6            4.0         Excellent        Satisfied             Relavent
# 7            3.0              Good          Neutral             Relavent
# 8            3.0              Fair          Neutral           Irrevalent
# 9            5.0         Excellent   Very Satisfied        Very Relevant
# 10           4.0         Excellent        Satisfied        Very Relevant
#
#     College-infracture  Hygene Career_guide Recommendation-others  \
# 1                  4.0     4.0         Fair                Likely
# 2                  4.0     4.0         Good           Very likely
# 3                  4.0     3.0         Fair               Neutral
# 4                  4.0     3.0         Fair               Neutral
# 5                  3.0     3.0         Good               Neutral
# 6                  4.0     5.0    Excellent           Very likely
# 7                  3.0     3.0         Fair                Likely
# 8                  4.0     4.0         Good                Likely
# 9                  3.0     4.0    Excellent                Likely
# 10                 5.0     4.0         Good           Very likely
#
#     College Association_less than 1 year  \
# 1                                  False
# 2                                  False
# 3                                   True
# 4                                   True
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
#
#     College Association_more than 3 years  Academic_Resources_Partially  \
# 1                                    True                          True
# 2                                    True                         False
# 3                                   False                         False
# 4                                   False                         False
# 5                                    True                         False
# 6                                    True                         False
# 7                                    True                          True
# 8                                    True                         False
# 9                                    True                          True
# 10                                   True                         False
#
#     Academic_Resources_Yes  extracurricular-activities_Partially  \
# 1                    False                                 False
# 2                     True                                  True
# 3                     True                                 False
# 4                     True                                 False
# 5                     True                                 False
# 6                     True                                 False
# 7                    False                                  True
# 8                     True                                 False
# 9                    False                                  True
# 10                    True                                  True
#
#     extracurricular-activities_Yes  Support_No  Support_Yes  Social_value_No  \
# 1                             True       False        False            False
# 2                            False       False        False            False
# 3                             True       False         True            False
# 4                             True       False         True            False
# 5                             True       False         True            False
# 6                             True       False         True            False
# 7                            False       False        False            False
# 8                             True       False        False             True
# 9                            False       False         True            False
# 10                           False       False         True            False
#
#     Social_value_Yes
# 1              False
# 2              False
# 3               True
# 4               True
# 5               True
# 6               True
# 7              False
# 8              False
# 9              False
# 10              True

# %%
# Ordinal encode ordinal categorical columns
ordinal_cols = {
    'Academic_standard': ['Poor', 'Fair', 'Good', 'Excellent'],
    'Teaching_quality': ['Dissatisfied', 'Neutral', 'Satisfied','Very Satisfied'],
    'Curriculum_relevance': ['Not Sure', 'Irrevalent', 'Relavent', 'Very Relevant', 'Neutral'],
    'Career_guide': ['Poor', 'Fair', 'Good', 'Excellent'],
    'Recommendation-others': ['Very Unlikely', 'Unlikely', 'Neutral', 'Likely', 'Very likely']
}

# Handle NaN values before encoding
# Option 1: Impute NaN with the most frequent value
for col in ordinal_cols:
    # Calculate the most frequent value
    most_frequent_value = new_df[col].mode()[0]
    # Fill NaN with the most frequent value
    new_df[col].fillna(most_frequent_value, inplace=True)

# Option 2: Remove rows with NaN values (use with caution, might lead to data loss)
# for col in ordinal_cols:
#     new_df.dropna(subset=[col], inplace=True)

for col, categories in ordinal_cols.items():
    ordinal_encoder = OrdinalEncoder(categories=[categories])
    df_encoded[col] = ordinal_encoder.fit_transform(new_df[[col]])

# Display encoded data
print("\nEncoded DataFrame:")
print(df_encoded)
# Out:
# Encoded DataFrame:
#      College_rate  Academic_standard  Teaching_quality  Curriculum_relevance  \
# 1             4.0                1.0               1.0                   2.0
# 2             3.0                2.0               2.0                   4.0
# 3             3.0                2.0               1.0                   4.0
# 4             3.0                2.0               1.0                   4.0
# 5             3.0                2.0               1.0                   4.0
# ..            ...                ...               ...                   ...
# 345           4.0                2.0               3.0                   4.0
# 346           2.0                2.0               0.0                   1.0
# 347           3.0                0.0               0.0                   4.0
# 348           4.0                2.0               2.0                   2.0
# 349           3.0                1.0               1.0                   4.0
#
#      College-infracture  Hygene  Career_guide  Recommendation-others  \
# 1                   4.0     4.0           1.0                    3.0
# 2                   4.0     4.0           2.0                    4.0
# 3                   4.0     3.0           1.0                    2.0
# 4                   4.0     3.0           1.0                    2.0
# 5                   3.0     3.0           2.0                    2.0
# ..                  ...     ...           ...                    ...
# 345                 4.0     4.0           2.0                    3.0
# 346                 1.0     1.0           1.0                    1.0
# 347                 3.0     3.0           0.0                    2.0
# 348                 4.0     4.0           2.0                    3.0
# 349                 3.0     3.0           1.0                    2.0
#
#      College Association_less than 1 year  \
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                    True
# 5                                   False
# ..                                    ...
# 345                                  True
# 346                                 False
# 347                                  True
# 348                                  True
# 349                                  True
#
#      College Association_more than 3 years  Academic_Resources_Partially  \
# 1                                     True                          True
# 2                                     True                         False
# 3                                    False                         False
# 4                                    False                         False
# 5                                     True                         False
# ..                                     ...                           ...
# 345                                  False                         False
# 346                                  False                          True
# 347                                  False                          True
# 348                                  False                         False
# 349                                  False                          True
#
#      Academic_Resources_Yes  extracurricular-activities_Partially  \
# 1                     False                                 False
# 2                      True                                  True
# 3                      True                                 False
# 4                      True                                 False
# 5                      True                                 False
# ..                      ...                                   ...
# 345                   False                                 False
# 346                   False                                 False
# 347                   False                                 False
# 348                    True                                 False
# 349                   False                                  True
#
#      extracurricular-activities_Yes  Support_No  Support_Yes  Social_value_No  \
# 1                              True       False        False            False
# 2                             False       False        False            False
# 3                              True       False         True            False
# 4                              True       False         True            False
# 5                              True       False         True            False
# ..                              ...         ...          ...              ...
# 345                            True       False        False             True
# 346                           False       False        False             True
# 347                           False        True        False            False
# 348                            True       False         True            False
# 349                           False       False        False            False
#
#      Social_value_Yes
# 1               False
# 2               False
# 3                True
# 4                True
# 5                True
# ..                ...
# 345             False
# 346             False
# 347              True
# 348              True
# 349             False
#
# [349 rows x 18 columns]
# <ipython-input-107-4afb03c9b690>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_df[col].fillna(most_frequent_value, inplace=True)

# %%
df_encoded.count()
# Out:
# College_rate                             347
# Academic_standard                        349
# Teaching_quality                         349
# Curriculum_relevance                     349
# College-infracture                       346
# Hygene                                   343
# Career_guide                             349
# Recommendation-others                    349
# College Association_less than 1 year     349
# College Association_more than 3 years    349
# Academic_Resources_Partially             349
# Academic_Resources_Yes                   349
# extracurricular-activities_Partially     349
# extracurricular-activities_Yes           349
# Support_No                               349
# Support_Yes                              349
# Social_value_No                          349
# Social_value_Yes                         349
# dtype: int64

# %%
categories = [
    'College_rate', 'Academic_standard', 'Teaching_quality', 'Curriculum_relevance',
    'College-infracture', 'Hygene', 'Career_guide', 'Recommendation-others',
    'College Association_less than 1 year', 'College Association_more than 3 years',
    'Academic_Resources_Partially', 'Academic_Resources_Yes',
    'extracurricular-activities_Partially', 'extracurricular-activities_Yes',
    'Support_No', 'Support_Yes', 'Social_value_No', 'Social_value_Yes'
]

counts = [
    347, 349, 349, 349, 346, 343, 349, 349,
    349, 349, 349, 349, 349, 349, 349, 349, 349, 349
]

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title("Survey Response Distribution", fontsize=16)
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Show the plot
plt.show()

# %%
df_encoded.plot(kind='hist', subplots=True, layout=(3,3), figsize=(15,12))
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>]], dtype=object)

# %%
sns.pairplot(df_encoded)

# %%
df_encoded.corr()
# Out:
#                                        College_rate  Academic_standard  \
# College_rate                               1.000000           0.449413
# Academic_standard                          0.449413           1.000000
# Teaching_quality                           0.283720           0.436290
# Curriculum_relevance                      -0.055037          -0.052407
# College-infracture                         0.429586           0.340206
# Hygene                                     0.336396           0.147167
# Career_guide                               0.230073           0.464881
# Recommendation-others                      0.423643           0.518434
# College Association_less than 1 year      -0.099724           0.014885
# College Association_more than 3 years      0.092636           0.117133
# Academic_Resources_Partially              -0.024722          -0.258598
# Academic_Resources_Yes                     0.129560           0.350659
# extracurricular-activities_Partially      -0.082628          -0.224502
# extracurricular-activities_Yes             0.246112           0.332188
# Support_No                                -0.162815          -0.278724
# Support_Yes                                0.212544           0.417367
# Social_value_No                           -0.173713          -0.163928
# Social_value_Yes                           0.198553           0.314407
#
#                                        Teaching_quality  Curriculum_relevance  \
# College_rate                                   0.283720             -0.055037
# Academic_standard                              0.436290             -0.052407
# Teaching_quality                               1.000000             -0.049681
# Curriculum_relevance                          -0.049681              1.000000
# College-infracture                             0.101052             -0.014477
# Hygene                                        -0.054967              0.034891
# Career_guide                                   0.314587             -0.041798
# Recommendation-others                          0.278326             -0.037520
# College Association_less than 1 year           0.051275             -0.088578
# College Association_more than 3 years         -0.039554              0.028876
# Academic_Resources_Partially                  -0.156398              0.053454
# Academic_Resources_Yes                         0.219987             -0.107927
# extracurricular-activities_Partially          -0.190388              0.063814
# extracurricular-activities_Yes                 0.235326             -0.074746
# Support_No                                    -0.105352             -0.007062
# Support_Yes                                    0.295793             -0.091926
# Social_value_No                               -0.070365              0.060156
# Social_value_Yes                               0.218202             -0.102029
#
#                                        College-infracture    Hygene  \
# College_rate                                     0.429586  0.336396
# Academic_standard                                0.340206  0.147167
# Teaching_quality                                 0.101052 -0.054967
# Curriculum_relevance                            -0.014477  0.034891
# College-infracture                               1.000000  0.532744
# Hygene                                           0.532744  1.000000
# Career_guide                                     0.230699 -0.051445
# Recommendation-others                            0.378499  0.219045
# College Association_less than 1 year            -0.031179 -0.144909
# College Association_more than 3 years            0.137213  0.116229
# Academic_Resources_Partially                    -0.210482 -0.025565
# Academic_Resources_Yes                           0.355333  0.084792
# extracurricular-activities_Partially            -0.184757 -0.061237
# extracurricular-activities_Yes                   0.348027  0.134950
# Support_No                                      -0.151051 -0.018722
# Support_Yes                                      0.267229  0.095378
# Social_value_No                                 -0.171973 -0.138388
# Social_value_Yes                                 0.239153  0.069074
#
#                                        Career_guide  Recommendation-others  \
# College_rate                               0.230073               0.423643
# Academic_standard                          0.464881               0.518434
# Teaching_quality                           0.314587               0.278326
# Curriculum_relevance                      -0.041798              -0.037520
# College-infracture                         0.230699               0.378499
# Hygene                                    -0.051445               0.219045
# Career_guide                               1.000000               0.491170
# Recommendation-others                      0.491170               1.000000
# College Association_less than 1 year       0.171925              -0.019950
# College Association_more than 3 years      0.005345               0.187520
# Academic_Resources_Partially              -0.391731              -0.305318
# Academic_Resources_Yes                     0.474505               0.414354
# extracurricular-activities_Partially      -0.269517              -0.221757
# extracurricular-activities_Yes             0.372938               0.419587
# Support_No                                -0.311393              -0.231609
# Support_Yes                                0.469556               0.370466
# Social_value_No                           -0.226856              -0.394280
# Social_value_Yes                           0.325408               0.400523
#
#                                        College Association_less than 1 year  \
# College_rate                                                      -0.099724
# Academic_standard                                                  0.014885
# Teaching_quality                                                   0.051275
# Curriculum_relevance                                              -0.088578
# College-infracture                                                -0.031179
# Hygene                                                            -0.144909
# Career_guide                                                       0.171925
# Recommendation-others                                             -0.019950
# College Association_less than 1 year                               1.000000
# College Association_more than 3 years                             -0.384606
# Academic_Resources_Partially                                      -0.171238
# Academic_Resources_Yes                                             0.181409
# extracurricular-activities_Partially                              -0.035635
# extracurricular-activities_Yes                                    -0.044642
# Support_No                                                        -0.124501
# Support_Yes                                                        0.010609
# Social_value_No                                                   -0.107576
# Social_value_Yes                                                   0.048213
#
#                                        College Association_more than 3 years  \
# College_rate                                                        0.092636
# Academic_standard                                                   0.117133
# Teaching_quality                                                   -0.039554
# Curriculum_relevance                                                0.028876
# College-infracture                                                  0.137213
# Hygene                                                              0.116229
# Career_guide                                                        0.005345
# Recommendation-others                                               0.187520
# College Association_less than 1 year                               -0.384606
# College Association_more than 3 years                               1.000000
# Academic_Resources_Partially                                        0.000998
# Academic_Resources_Yes                                              0.038935
# extracurricular-activities_Partially                               -0.002914
# extracurricular-activities_Yes                                      0.056628
# Support_No                                                         -0.003073
# Support_Yes                                                         0.069916
# Social_value_No                                                    -0.104671
# Social_value_Yes                                                    0.093684
#
#                                        Academic_Resources_Partially  \
# College_rate                                              -0.024722
# Academic_standard                                         -0.258598
# Teaching_quality                                          -0.156398
# Curriculum_relevance                                       0.053454
# College-infracture                                        -0.210482
# Hygene                                                    -0.025565
# Career_guide                                              -0.391731
# Recommendation-others                                     -0.305318
# College Association_less than 1 year                      -0.171238
# College Association_more than 3 years                      0.000998
# Academic_Resources_Partially                               1.000000
# Academic_Resources_Yes                                    -0.781982
# extracurricular-activities_Partially                       0.271750
# extracurricular-activities_Yes                            -0.307686
# Support_No                                                 0.035386
# Support_Yes                                               -0.295070
# Social_value_No                                            0.157616
# Social_value_Yes                                          -0.294681
#
#                                        Academic_Resources_Yes  \
# College_rate                                         0.129560
# Academic_standard                                    0.350659
# Teaching_quality                                     0.219987
# Curriculum_relevance                                -0.107927
# College-infracture                                   0.355333
# Hygene                                               0.084792
# Career_guide                                         0.474505
# Recommendation-others                                0.414354
# College Association_less than 1 year                 0.181409
# College Association_more than 3 years                0.038935
# Academic_Resources_Partially                        -0.781982
# Academic_Resources_Yes                               1.000000
# extracurricular-activities_Partially                -0.257774
# extracurricular-activities_Yes                       0.410752
# Support_No                                          -0.155163
# Support_Yes                                          0.398119
# Social_value_No                                     -0.240119
# Social_value_Yes                                     0.326943
#
#                                        extracurricular-activities_Partially  \
# College_rate                                                      -0.082628
# Academic_standard                                                 -0.224502
# Teaching_quality                                                  -0.190388
# Curriculum_relevance                                               0.063814
# College-infracture                                                -0.184757
# Hygene                                                            -0.061237
# Career_guide                                                      -0.269517
# Recommendation-others                                             -0.221757
# College Association_less than 1 year                              -0.035635
# College Association_more than 3 years                             -0.002914
# Academic_Resources_Partially                                       0.271750
# Academic_Resources_Yes                                            -0.257774
# extracurricular-activities_Partially                               1.000000
# extracurricular-activities_Yes                                    -0.727103
# Support_No                                                         0.075453
# Support_Yes                                                       -0.282918
# Social_value_No                                                    0.097521
# Social_value_Yes                                                  -0.259206
#
#                                        extracurricular-activities_Yes  \
# College_rate                                                 0.246112
# Academic_standard                                            0.332188
# Teaching_quality                                             0.235326
# Curriculum_relevance                                        -0.074746
# College-infracture                                           0.348027
# Hygene                                                       0.134950
# Career_guide                                                 0.372938
# Recommendation-others                                        0.419587
# College Association_less than 1 year                        -0.044642
# College Association_more than 3 years                        0.056628
# Academic_Resources_Partially                                -0.307686
# Academic_Resources_Yes                                       0.410752
# extracurricular-activities_Partially                        -0.727103
# extracurricular-activities_Yes                               1.000000
# Support_No                                                  -0.231553
# Support_Yes                                                  0.407051
# Social_value_No                                             -0.135921
# Social_value_Yes                                             0.384950
#
#                                        Support_No  Support_Yes  \
# College_rate                            -0.162815     0.212544
# Academic_standard                       -0.278724     0.417367
# Teaching_quality                        -0.105352     0.295793
# Curriculum_relevance                    -0.007062    -0.091926
# College-infracture                      -0.151051     0.267229
# Hygene                                  -0.018722     0.095378
# Career_guide                            -0.311393     0.469556
# Recommendation-others                   -0.231609     0.370466
# College Association_less than 1 year    -0.124501     0.010609
# College Association_more than 3 years   -0.003073     0.069916
# Academic_Resources_Partially             0.035386    -0.295070
# Academic_Resources_Yes                  -0.155163     0.398119
# extracurricular-activities_Partially     0.075453    -0.282918
# extracurricular-activities_Yes          -0.231553     0.407051
# Support_No                               1.000000    -0.317884
# Support_Yes                             -0.317884     1.000000
# Social_value_No                          0.197488    -0.172955
# Social_value_Yes                        -0.214546     0.358803
#
#                                        Social_value_No  Social_value_Yes
# College_rate                                 -0.173713          0.198553
# Academic_standard                            -0.163928          0.314407
# Teaching_quality                             -0.070365          0.218202
# Curriculum_relevance                          0.060156         -0.102029
# College-infracture                           -0.171973          0.239153
# Hygene                                       -0.138388          0.069074
# Career_guide                                 -0.226856          0.325408
# Recommendation-others                        -0.394280          0.400523
# College Association_less than 1 year         -0.107576          0.048213
# College Association_more than 3 years        -0.104671          0.093684
# Academic_Resources_Partially                  0.157616         -0.294681
# Academic_Resources_Yes                       -0.240119          0.326943
# extracurricular-activities_Partially          0.097521         -0.259206
# extracurricular-activities_Yes               -0.135921          0.384950
# Support_No                                    0.197488         -0.214546
# Support_Yes                                  -0.172955          0.358803
# Social_value_No                               1.000000         -0.396647
# Social_value_Yes                             -0.396647          1.000000

# %%
df_encoded.plot(kind='box', subplots=True, layout=(3,3), figsize=(15,12))
# Out:
# College_rate                Axes(0.125,0.653529;0.227941x0.226471)
# Academic_standard        Axes(0.398529,0.653529;0.227941x0.226471)
# Teaching_quality         Axes(0.672059,0.653529;0.227941x0.226471)
# Curriculum_relevance        Axes(0.125,0.381765;0.227941x0.226471)
# College-infracture       Axes(0.398529,0.381765;0.227941x0.226471)
# Hygene                   Axes(0.672059,0.381765;0.227941x0.226471)
# Career_guide                    Axes(0.125,0.11;0.227941x0.226471)
# Recommendation-others        Axes(0.398529,0.11;0.227941x0.226471)
# dtype: object

# %%
df_encoded['College_rate'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_encoded['Hygene'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
for column in df_encoded.columns[:8]:
    plt.figure(figsize=(5, 5))
    df_encoded[column].value_counts().plot(kind='pie', autopct='%0.1f%%')
    plt.title(f'{column}')
    plt.ylabel('')
    plt.show()

# %%
sns.boxplot(x='College_rate', y='Academic_standard', data=df_encoded)
# Out:
# <Axes: xlabel='College_rate', ylabel='Academic_standard'>

# %%
Open_ended_columns = df[['Please share any suggestions for improving academic excellence at the college. (Open-ended)',
                         'What are the top three strengths of the college? (Open-ended)',
                         'What are the top three areas where the college needs improvement? (Open-ended)',
                         'Please share any additional comments or experiences regarding the college. (Open-ended)'
                       ]]
Open_ended_df = Open_ended_columns.rename(columns = {'Please share any suggestions for improving academic excellence at the college. (Open-ended)':'Suggestion',
                                                   'What are the top three strengths of the college? (Open-ended)':'Strength',
                                                   'What are the top three areas where the college needs improvement? (Open-ended)':'Improvement',
                                                   'Please share any additional comments or experiences regarding the college. (Open-ended)':'Additional_comments'
                                            })

Open_ended_df.tail()
# Out:
#                                             Suggestion  \
# 345                                           nothing
# 346                                                NaN
# 347  I hope that our college can focus on better te...
# 348                                                NaN
# 349                                No any suggestions
#
#                                               Strength  \
# 345                                           teacher
# 346                                                NaN
# 347                                                NaN
# 348  This college education is excellent and manage...
# 349                                                 No
#
#                                            Improvement  \
# 345                            proper break every day
# 346                           Play ground \nCanteen \n
# 347  Library( books of Library needs to be changes ...
# 348                                                 \n
# 349                                                 No
#
#                                    Additional_comments
# 345                                           nothing
# 346                                                NaN
# 347  Class 11 and 12 should also be given chance to...
# 348                                                NaN
# 349                                                 No

# %%
Open_ended_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 1 to 349
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Suggestion           157 non-null    object
#  1   Strength             155 non-null    object
#  2   Improvement          165 non-null    object
#  3   Additional_comments  93 non-null     object
# dtypes: object(4)
# memory usage: 11.0+ KB

# %%
Open_ended_df.describe()
# Out:
#        Suggestion  Strength Improvement Additional_comments
# count         157       155         165                  93
# unique        142       150         160                  78
# top      Nothing   Nothing     Nothing             Nothing
# freq            8         4           5                   7

# %%
Open_ended_df.isnull().sum()
# Out:
# Suggestion             192
# Strength               194
# Improvement            184
# Additional_comments    256
# dtype: int64

# %%
Open_ended_df.dropna(inplace=True)
#Open_ended_df.info()

# %%
#Open_ended_df.isnull().sum()
# Out:
# Suggestion             0
# Strength               0
# Improvement            0
# Additional_comments    0
# dtype: int64

# %%
Open_ended_df['Suggestion'].value_counts()
# Out:
# Suggestion
# Nothing                                                                                                                                                                                                                                                                      8
# No                                                                                                                                                                                                                                                                           4
# Can be better                                                                                                                                                                                                                                                                2
# Nothing                                                                                                                                                                                                                                                                      2
# Classroom                                                                                                                                                                                                                                                                    2
#                                                                                                                                                                                                                                                                             ..
# More better can be done                                                                                                                                                                                                                                                      1
# College should make their students engaged in extra curriculam activities too related to study.College should give equal opportunity either to the talented or poor students without any bias.College need to provide book to their students so that we can learn easily.    1
# nothing                                                                                                                                                                                                                                                                      1
# I hope that our college can focus on better teaching system as me and my friend haven't understand a single thing in account subject. If this situation will be same in class 12 then many are gonna fail                                                                    1
# No any suggestions                                                                                                                                                                                                                                                           1
# Name: count, Length: 142, dtype: int64

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(Open_ended_df)
prof.to_file(output_file='MBM_excellence.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00, 79.32it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **Data CLeaning**

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus=[]

for i in Open_ended_df.index:
  # Convert the value to string before applying re.sub
  review = str(Open_ended_df.loc[i, 'Additional_comments'])
  review = re.sub('[^a-zA-Z]', ' ', review)
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus
# Out:
# ['noth',
#  'comment',
#  'love mbmc happi bring posit chang colleg recommend mbmc student well',
#  'great experi',
#  'practic exam late',
#  'intrins extern exposur train med conduct',
#  'physic lab improv',
#  'overal colleg experi good might better frequent placement opportun',
#  'comment',
#  'canteen menu',
#  'meet expect',
#  'experi good would prefer class morn',
#  'meet expect',
#  'regard holiday public holiday given student stay far home also consid holiday given',
#  'comput lab work properli finish practic time internet slow',
#  'improv better overal facil recommend',
#  'inform gather faculti student',
#  'good',
#  'add sport new equip',
#  'assain much',
#  'commun senior student',
#  'good',
#  'fine',
#  'ohh',
#  'canteen food improv cost',
#  'person noth good day',
#  'noth',
#  'noth',
#  'pleas separ section class scienc bring one physic teacher',
#  'good',
#  'better',
#  'dont',
#  '',
#  'pleas finish cours time',
#  'teacher teach well like sad subject sir th sem understand je teach',
#  'need power comput lab',
#  'still shock got qaa certifi even singl standard met',
#  'noth',
#  'kei xaina sakyo mathi haldeko xu naramro lagey sorri hai sorri',
#  'noth',
#  'feel good',
#  'noth',
#  'noo',
#  '',
#  'know',
#  'noth',
#  '',
#  'noth',
#  'confid',
#  'comment',
#  'good',
#  'good colleg',
#  '',
#  'comment',
#  'recent join bb program colleg feel',
#  'want collg improv commun skill well want market good collg good student less',
#  'noth',
#  'need classroom perman plz',
#  'better',
#  'good',
#  'nice',
#  'fine',
#  'th th sem hope uniform necessari enter colleg',
#  'improv activ',
#  'would like request colleg tour excurs refresh activ increas person growth activ student',
#  'comment',
#  'comment',
#  'overal colleg fulfil requir standard good institut',
#  'current work app develop offic time difficult carri one extra dress shoe bag wear colleg dress day long pm would better colleg allow wear dress not messi inform issu not mine mani student face issu',
#  'neutral',
#  'provid us book extra curricular activ',
#  '',
#  'noth',
#  '']

# %% [markdown]
# **Data Transformation**
#
# **Creating a Bag of Words model**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1200)

# %%
X = cv.fit_transform(corpus).toarray()    #feeding the corpus to model
y = df_encoded.loc[Open_ended_df.index, 'Recommendation-others'].values
#y = df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((74, 169), (74,))

# %%
#Saving BoW dictionary to later use in prediction
import pickle
bow_path = 'c1_BoW_Sentiment_Model.pkl'
pickle.dump(cv, open(bow_path, "wb"))

# %% [markdown]
# **Dividing datasets to train and test sets**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# **Min-Max Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# **Model fitting(Naive Based)**

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
print(classifier.fit(X_train, y_train))
# Exporting NB Classifier to later use in prediction
import joblib
joblib.dump(classifier, 'c2_Classifier_Sentiment_Model')
# Out:
# GaussianNB()
# ['c2_Classifier_Sentiment_Model']

# %% [markdown]
# **Model Performance**

# %%
# checking the accuracies
print("Training Accuracy :", classifier.score(X_train, y_train))
print("Testing Accuracy :", classifier.score(X_test, y_test))
# Out:
# Training Accuracy : 0.847457627118644
# Testing Accuracy : 0.3333333333333333

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[0 0 0 0]
#  [3 2 3 0]
#  [0 1 3 2]
#  [0 1 0 0]]
# 0.3333333333333333

# %%
#Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

model = RandomForestClassifier()

# fitting the training data to the model
model.fit(X_train, y_train)

# predicting the test set results
y_pred = model.predict(X_test)

# checking the accuracies
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))

# making the confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# Training Accuracy : 0.9152542372881356
# Testing Accuracy : 0.4
# [[1 7 0]
#  [1 5 0]
#  [1 0 0]]
# 0.4

# %%
#Using NLP
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

# creating the model
model = MLPClassifier()

# fitting the training data to the model
model.fit(X_train, y_train)

# predicting the test set results
y_pred = model.predict(X_test)

# checking the accuracies
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))

# making the confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy : 0.9152542372881356
# Testing Accuracy : 0.4
# [[1 7 0]
#  [1 5 0]
#  [1 0 0]]
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ##**Transformer based Sentiment analysis**

# %%
Open_ended_df.dropna(inplace=True)
Open_ended_df.reset_index(drop=True, inplace=True)      #reset index

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sample = Open_ended_df['Strength'][1]
sample
# Out:
# 'Infrastructure, faculty members, team etc.'

# %%
import nltk
nltk.download('punkt_tab')
tokens = nltk.word_tokenize(Open_ended_df['Strength'][5])
print(tokens)
tokens[:10]
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Good', 'Teaching', 'environment']
# ['Good', 'Teaching', 'environment']

# %%
nltk.download('averaged_perceptron_tagger_eng')
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('Good', 'JJ'), ('Teaching', 'NNP'), ('environment', 'NN')]

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# (S (PERSON Good/JJ) Teaching/NNP environment/NN)

# %% [markdown]
# **VADAR**

# %% [markdown]
# We will use NLTK's SentimentIntensityAnalyzer to get the neg/neu/pos scores of the text.
#
# * This uses the "Bag of Words" approcah
# * stop words are removed
# * each word is scored and combined to total score

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia = SentimentIntensityAnalyzer()

# %%
for item in tqdm(Open_ended_df['Strength'].values[:10]):
  print(item)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# low fees AND QUALITY EDUCATION
# Infrastructure, faculty members, team etc.
# Extra curriculars, resources/ infrastructure and the fact that we can reach out to the administration anytime if we have any issues.
# Cleaniness, lab library facility, building strucure
# Infrastructure,cleanliness,
# Good Teaching environment
# Infrastructure, Quality education, Qualified Teachers
# Cleanliness , teaching quality , administrative responsibility
# Management ,infrastructure ,punctuality
# Good multimedia teaching

# %%
Open_ended_df['Strength'][0]
# Out:
# 'low fees AND QUALITY EDUCATION'

# %%
sia.polarity_scores(Open_ended_df['Strength'][0])
# Out:
# {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.2732}

# %%
#The polarity score on the entire dataset
res={}
for i, item in tqdm(Open_ended_df.iterrows(), total=len(Open_ended_df)):
  text = item['Strength']
  #myid = item['id']
  res[i] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders.head()
# Out:
#      neg    neu    pos  compound
# 0  0.344  0.656  0.000   -0.2732
# 1  0.000  1.000  0.000    0.0000
# 2  0.000  0.948  0.052    0.0258
# 3  0.000  1.000  0.000    0.0000
# 4  0.000  1.000  0.000    0.0000

# %%
# Convert res to DataFrame
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index':'Open_ended_df_index'})
#the merge function will now merge using the 'Open_ended_df_index'
vaders = vaders.merge(Open_ended_df, how='left', left_on='Open_ended_df_index', right_index=True)
vaders.tail()
# Out:
#     Open_ended_df_index  neg    neu    pos  compound  \
# 9                     9  0.0  0.408  0.592    0.4404
# 10                   10  0.0  0.484  0.516    0.4939
# 11                   11  0.0  0.256  0.744    0.4404
# 12                   12  0.0  0.556  0.444    0.4939
# 13                   13  0.0  0.376  0.624    0.8074
#
#                                            Suggestion  \
# 9   I am good but lets see what happen and then i ...
# 10  Provide academic calender\nPlease Don't do com...
# 11  It would be better if the classes for CSIT wer...
# 12                         More training and workshop
# 13  Subject books should be edited version and the...
#
#                                              Strength  \
# 9                            Good multimedia teaching
# 10    Management , infrastructure, friendly teachers
# 11                                     Good teachers
# 12  Management infrastructure punctuality friendly...
# 13  The teachers are good. Friendly environment. S...
#
#                                           Improvement  \
# 9   Wifi facilities \nCanteen menu should be chang...
# 10                          Lab, library, playground
# 11  Laboratory, recreation materials like other in...
# 12                            Lab library playground
# 13                                      Lab resources
#
#                                   Additional_comments
# 9                                        Canteen menu
# 10                      Didn't meet the expectations
# 11  The experience is good but I would prefer my c...
# 12                          Didn't meet expectations
# 13  Regarding the holidays, public holidays are gi...

# %%
#plot VADERs result
ax = sns.barplot(data=vaders, x='Open_ended_df_index', y='compound')
ax.set_title('Compound Score')
plt.show()

# %%
figs, axs = plt.subplots(1, 3, figsize=(12, 3))

# Create a new data frame from the existing vaders
# which has the mean of each category grouped by the index
df_pos = vaders.groupby('Open_ended_df_index')['pos'].mean().reset_index()
df_neu = vaders.groupby('Open_ended_df_index')['neu'].mean().reset_index()
df_neg = vaders.groupby('Open_ended_df_index')['neg'].mean().reset_index()

# Plot the positive sentiment
sns.barplot(data=df_pos, x='Open_ended_df_index', y='pos', ax=axs[0]) # x now uses the Open_ended_df_index and y now uses the pos data in the new dataframe.
axs[0].set_title('Positive')

# Plot the neutral sentiment
sns.barplot(data=df_neu, x='Open_ended_df_index', y='neu', ax=axs[1]) # x now uses the Open_ended_df_index and y now uses the neu data in the new dataframe.
axs[1].set_title('Neutral')
# Plot the negative sentiment
sns.barplot(data=df_neg, x='Open_ended_df_index', y='neg', ax=axs[2]) # x now uses the Open_ended_df_index and y now uses the neg data in the new dataframe.
axs[2].set_title('Negative')

#plt.tight_layout()
plt.show()

# %%
data = [df_pos['pos'].mean(), df_neu['neu'].mean(), df_neg['neg'].mean()]
labels = ['Positive', 'Neutral', 'Negative']

# Create pie chart
plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
Open_ended_df.columns
# Out:
# Index(['Suggestion', 'Strength', 'Improvement', 'Additional_comments'], dtype='object')

# %%
sns.pairplot(vaders, vars=['pos', 'neu', 'neg', 'compound'])
